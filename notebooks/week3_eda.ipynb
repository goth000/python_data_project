# %%
import json
from pathlib import Path

import pandas as pd

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-ffc08d17-58b9-43be-b60c-145fb27fae3b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ffc08d17-58b9-43be-b60c-145fb27fae3b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Raw JSON data from Open-Meteo API was loaded for normalization.

# %%
raw_path = "/content/2026-05-27_17-16-02.json"

with open(raw_path, "r", encoding="utf-8") as file:
    data = json.load(file)

print(type(data))
print(data.keys())
# Out:
# <class 'dict'>
# dict_keys(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'hourly_units', 'hourly'])

# %% [markdown]
# One row in the normalized dataset represents one hour of weather observations in Tokyo.

# %%
hourly = data["hourly"]

df = pd.DataFrame({
    "ts": hourly["time"],
    "temperature_2m": hourly["temperature_2m"],
    "relative_humidity_2m": hourly["relative_humidity_2m"],
    "precipitation": hourly["precipitation"],
    "wind_speed_10m": hourly["wind_speed_10m"],
    "city_id": "JP_TYO",
})

# %% [markdown]
# The initial DataFrame structure was inspected using head(), shape and dtypes.

# %%
df.head()
# Out:
#                  ts  temperature_2m  relative_humidity_2m  precipitation  \
# 0  2024-05-01T00:00            19.6                    93            0.0
# 1  2024-05-01T01:00            19.9                    90            0.0
# 2  2024-05-01T02:00            19.2                    94            0.0
# 3  2024-05-01T03:00            18.9                    97            0.0
# 4  2024-05-01T04:00            19.1                    92            0.0
#
#    wind_speed_10m city_id
# 0             1.6  JP_TYO
# 1             1.3  JP_TYO
# 2             2.5  JP_TYO
# 3             3.3  JP_TYO
# 4             7.4  JP_TYO

# %%
df.shape
# Out:
# (168, 6)

# %%
df.dtypes
# Out:
# ts                       object
# temperature_2m          float64
# relative_humidity_2m      int64
# precipitation           float64
# wind_speed_10m          float64
# city_id                  object
# dtype: object

# %% [markdown]
# Datetime conversion, numeric conversion and duplicate removal were applied during normalization.

# %%
df["ts"] = pd.to_datetime(df["ts"])

numeric_columns = [
    "temperature_2m",
    "relative_humidity_2m",
    "precipitation",
    "wind_speed_10m",
]

for column in numeric_columns:
    df[column] = pd.to_numeric(df[column], errors="coerce")

df = df.drop_duplicates()

# %% [markdown]
# Missing values were checked after cleaning and normalization.

# %%
df.isna().sum()
# Out:
# ts                      0
# temperature_2m          0
# relative_humidity_2m    0
# precipitation           0
# wind_speed_10m          0
# city_id                 0
# dtype: int64

# %%
df.head()
# Out:
#                    ts  temperature_2m  relative_humidity_2m  precipitation  \
# 0 2024-05-01 00:00:00            19.6                    93            0.0
# 1 2024-05-01 01:00:00            19.9                    90            0.0
# 2 2024-05-01 02:00:00            19.2                    94            0.0
# 3 2024-05-01 03:00:00            18.9                    97            0.0
# 4 2024-05-01 04:00:00            19.1                    92            0.0
#
#    wind_speed_10m city_id
# 0             1.6  JP_TYO
# 1             1.3  JP_TYO
# 2             2.5  JP_TYO
# 3             3.3  JP_TYO
# 4             7.4  JP_TYO
